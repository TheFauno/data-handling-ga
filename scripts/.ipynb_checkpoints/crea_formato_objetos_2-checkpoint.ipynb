# %%
import pandas as pd
import sys
import xml.etree.ElementTree as ET
import csv
path = 'C:/Users/dazac/Downloads/datos mina/datos produccion/'

# %%
df_descarga = pd.read_csv(path+'generados/datos_descargas.csv')
df_descarga
# Out:
#         Type        Name          PositionedAt  CurrentLoad  MaximumDischarge
# 0    Crusher  Chancador1                  CS01          0.0                 1
# 1  Stockpile      Stock1     RS1_STOCKCR04_SME          0.0                99
# 2  Wastedump   Botadero1   UB1_TRANQUEESPA_EST          0.0                99
# 3  Wastedump   Botadero2  RB2_GUANACOCORTO_EST          0.0                99
# 4  Wastedump   Botadero3         RB1_ZORRO_EST          0.0                99

# %%
df_carga = pd.read_csv(path+'generados/datos_cargas.csv')
df_carga
# Out:
#    Name       PositionedAt  TransportationCapacity  LoadRate  DigRate  \
# 0  CF04       UB1_4390_EST                      36       326    12324
# 1  PA08  RF10A_4390_1032_1                      73        76    11258
# 2  PA09    RF9B_4135_902_1                      73       106    16869
# 3  PA10   RF11_4405_1124_1                      73       110    13665
# 4  PA11  RF10A_4390_1025_1                      74        71    12192
# 5  PA13  RF10A_4375_1005_1                      74        86    16022
# 6  PA14  RF10A_4390_1018_1                      74        73    17180
# 7  PA15    RF9B_4135_905_1                      36       219    12191
# 8  PA16     RS1_PARINA_SME                      36       193    11729
# 9  PA21  RF10A_4390_1028_1                      79        97    12053
#
#    CurrentLoad  IdealAmount Destination
# 0            0            0   Botadero1
# 1            0            0   Botadero2
# 2            0            0      Stock1
# ...

# %%
#cargar descargas para obtener nombres de estaciones de descarga
#leer nombres cargas
lugares_carga = list(df_carga.loc[:, 'PositionedAt'].values)
#leer nombres descargas
estaciones_descarga = list(df_descarga.loc[:, 'PositionedAt'].values)
df_carga_descarga = pd.DataFrame.merge(df_carga, df_descarga, left_on="Destination", right_on="Name", how="inner")
df_carga_descarga = df_carga_descarga.loc[:, ['PositionedAt_x', 'PositionedAt_y']]
df_carga_descarga
# Out:
#       PositionedAt_x        PositionedAt_y
# 0       UB1_4390_EST   UB1_TRANQUEESPA_EST
# 1  RF10A_4390_1032_1  RB2_GUANACOCORTO_EST
# 2  RF10A_4390_1025_1  RB2_GUANACOCORTO_EST
# 3  RF10A_4375_1005_1  RB2_GUANACOCORTO_EST
# 4    RF9B_4135_902_1     RS1_STOCKCR04_SME
# 5    RF9B_4135_905_1     RS1_STOCKCR04_SME
# 6     RS1_PARINA_SME     RS1_STOCKCR04_SME
# 7   RF11_4405_1124_1         RB1_ZORRO_EST
# 8  RF10A_4390_1018_1         RB1_ZORRO_EST
# 9  RF10A_4390_1028_1         RB1_ZORRO_EST

# %%
#cargar locaciones
tamanho_server = ['2,08920814597344','0,999103702764571','1,000000367302']
tamanho_nodo = ['1','1','1']
coordenadas_path = ['0','0','0']

df_locaciones = pd.read_csv(path+'generados/datos_nodos.csv')

object_type = []
name = []
x = []
y = []
z = []
lenght = []
width = []
height = []
path = []
prop = []
value = []
other = []

for index in range(len(df_locaciones.index)):
    
    #es pala
    if (df_locaciones.Name.iloc[index] in lugares_carga) and (df_locaciones.Name.iloc[index] != 'RS1_STOCKCR04_SME'):
        configuracion_task_seq = ';1;TaskIDNumber;1;none~1;TaskSequenceNumber;10;none~1;TaskName;;none~1;TaskBranchType;Always;none~1;TaskConditionOrProbability;0.0;none~1;TaskProcessType;Process Name;none~1;TaskProcessingTime;Random.Triangular(.1,.2,.3);Minutes~1;TaskProcessName;ProcesoPala;none~1;TaskSubmodelEntityCreationMethod;Create New (No Copying);none~1;TaskSubmodelEntityType;Same As Original Entity;none~1;TaskSubmodelStartingNode;;none~1;TaskSaveOriginalEntityReference;;none~1;TaskChangeoverLogicName;;none~1;TaskImmediatePredecessors;;none~1;TaskImmediateSuccessors;;none~1;TaskAutoCancelTrigger;All Immediate Predecessors Cancelled;none~1;TaskResourceRequirementsObjectType;Specific;none~1;TaskResourceRequirementsObjectName;;none~1;TaskResourceRequirementsObjectListName;;none~1;TaskResourceRequirementsSelectionGoal;Preferred Order;none~1;TaskResourceRequirementsSelectionExpression;Candidate.Object.Capacity.Remaining;none~1;TaskResourceRequirementsRequestMove;None;none~1;TaskResourceRequirementsDestinationNode;;none~1;TaskResourceRequirementsNumberOfObjects;1;none~1;TaskResourceRequirementsUnitsPerObject;1;none~1;TaskResourceRequirementsSelectionCondition;;none~1;TaskResourceRequirementsMustSimultaneouslySeize;False;none~1;TaskResourceRequirementsOffShiftRule;Suspend Processing;none~1;TaskResourceRequirementsKeepReservedCondition;True;none~1;TaskResourceRequirementsReservationTimeout;Math.Epsilon;Hours~1;TaskMaterialRequirementsActionType;Consume;none~1;TaskMaterialRequirementsConsumptionType;Material;none~1;TaskMaterialRequirementsProductionType;Material;none~1;TaskMaterialRequirementsMaterialName;;none~1;TaskMaterialRequirementsQuantity;1.0;none~1;TaskMaterialRequirementsLotID;;none~1;TaskMaterialRequirementsProductionDelayTime;0.0;Hours~1;TaskReadyAddOnProcess;;none~1;StartingTaskAddOnProcess;;none~1;FinishedTaskAddOnProcess;;none'
        #no se usa
        #destino = df_carga_descarga.loc[df_locaciones.Name.iloc[index] == df_carga_descarga.PositionedAt_x, 'PositionedAt_x'].values[0]
        
        object_type.append('Server')
        name.append(df_locaciones.Name.iloc[index])
        x.append('0')
        y.append('0')
        z.append('0')
        lenght.append(tamanho_server[0])
        width.append(tamanho_server[1])
        height.append(tamanho_server[2])
        path.append('0')
        prop.append('ProcessType')
        value.append('Task Sequence')
        other.append('none')
        
        object_type.append('Server')
        name.append(df_locaciones.Name.iloc[index])
        x.append('0')
        y.append('0')
        z.append('0')
        lenght.append(tamanho_server[0])
        width.append(tamanho_server[1])
        height.append(tamanho_server[2])
        path.append('0')
        prop.append('ProcessingTasks')
        value.append('1 Row')
        other.append(configuracion_task_seq)
        
        object_type.append('BasicNode')
        name.append("Input@"+df_locaciones.Name.iloc[index])
        x.append('0')
        y.append('0')
        z.append('0')
        lenght.append(tamanho_server[0])
        width.append(tamanho_server[1])
        height.append(tamanho_server[2])
        path.append('0')
        prop.append('EnteredAddOnProcess')
        value.append('EntradaInputPala')
        other.append('None')
        
        object_type.append('TransferNode')
        name.append("Output@"+df_locaciones.Name.iloc[index])
        x.append('0')
        y.append('0')
        z.append('0')
        lenght.append(tamanho_server[0])
        width.append(tamanho_server[1])
        height.append(tamanho_server[2])
        path.append('0')
        prop.append('EnteredAddOnProcess')
        value.append('EntradaOutputPala')
        other.append('None')
        
        object_type.append('TransferNode')
        name.append("Output@"+df_locaciones.Name.iloc[index])
        x.append('0')
        y.append('0')
        z.append('0')
        lenght.append(tamanho_server[0])
        width.append(tamanho_server[1])
        height.append(tamanho_server[2])
        path.append('0')
        prop.append('ExitedAddOnProcess')
        value.append('SalidaOutputPala')
        other.append('None')

    # si no lo encuentra en la lista de cargas no lo agrega al mapeo
    #es estacion de descarga
    elif df_locaciones.Name.iloc[index] in estaciones_descarga:
        configuracion_task_seq = ';1;TaskIDNumber;1;none~1;TaskSequenceNumber;10;none~1;TaskName;;none~1;TaskBranchType;Always;none~1;TaskConditionOrProbability;0.0;none~1;TaskProcessType;Process Name;none~1;TaskProcessingTime;Random.Triangular(.1,.2,.3);Minutes~1;TaskProcessName;ProcesoDescarga;none~1;TaskSubmodelEntityCreationMethod;Create New (No Copying);none~1;TaskSubmodelEntityType;Same As Original Entity;none~1;TaskSubmodelStartingNode;;none~1;TaskSaveOriginalEntityReference;;none~1;TaskChangeoverLogicName;;none~1;TaskImmediatePredecessors;;none~1;TaskImmediateSuccessors;;none~1;TaskAutoCancelTrigger;All Immediate Predecessors Cancelled;none~1;TaskResourceRequirementsObjectType;Specific;none~1;TaskResourceRequirementsObjectName;;none~1;TaskResourceRequirementsObjectListName;;none~1;TaskResourceRequirementsSelectionGoal;Preferred Order;none~1;TaskResourceRequirementsSelectionExpression;Candidate.Object.Capacity.Remaining;none~1;TaskResourceRequirementsRequestMove;None;none~1;TaskResourceRequirementsDestinationNode;;none~1;TaskResourceRequirementsNumberOfObjects;1;none~1;TaskResourceRequirementsUnitsPerObject;1;none~1;TaskResourceRequirementsSelectionCondition;;none~1;TaskResourceRequirementsMustSimultaneouslySeize;False;none~1;TaskResourceRequirementsOffShiftRule;Suspend Processing;none~1;TaskResourceRequirementsKeepReservedCondition;True;none~1;TaskResourceRequirementsReservationTimeout;Math.Epsilon;Hours~1;TaskMaterialRequirementsActionType;Consume;none~1;TaskMaterialRequirementsConsumptionType;Material;none~1;TaskMaterialRequirementsProductionType;Material;none~1;TaskMaterialRequirementsMaterialName;;none~1;TaskMaterialRequirementsQuantity;1.0;none~1;TaskMaterialRequirementsLotID;;none~1;TaskMaterialRequirementsProductionDelayTime;0.0;Hours~1;TaskReadyAddOnProcess;;none~1;StartingTaskAddOnProcess;;none~1;FinishedTaskAddOnProcess;;none'
        # agregar nuevo tipo de processing type
        object_type.append('Server')
        name.append(df_locaciones.Name.iloc[index])
        x.append('0')
        y.append('0')
        z.append('0')
        lenght.append(tamanho_server[0])
        width.append(tamanho_server[1])
        height.append(tamanho_server[2])
        path.append('0')
        prop.append('ProcessType')
        value.append('Task Sequence')
        other.append('none')
        
        object_type.append('Server')
        name.append(df_locaciones.Name.iloc[index])
        x.append('0')
        y.append('0')
        z.append('0')
        lenght.append(tamanho_server[0])
        width.append(tamanho_server[1])
        height.append(tamanho_server[2])
        path.append('0')
        prop.append('ProcessingTasks')
        value.append('1 Row')
        other.append(configuracion_task_seq)
        
        object_type.append('BasicNode')
        name.append("Input@"+df_locaciones.Name.iloc[index])
        x.append('0')
        y.append('0')
        z.append('0')
        lenght.append(tamanho_server[0])
        width.append(tamanho_server[1])
        height.append(tamanho_server[2])
        path.append('0')
        prop.append('EnteredAddOnProcess')
        value.append('EntradaInputDescarga')
        other.append('None')
        
        object_type.append('TransferNode')
        name.append("Output@"+df_locaciones.Name.iloc[index])
        x.append('0')
        y.append('0')
        z.append('0')
        lenght.append(tamanho_server[0])
        width.append(tamanho_server[1])
        height.append(tamanho_server[2])
        path.append('0')
        prop.append('EnteredAddOnProcess')
        value.append('EntradaOutputDescarga')
        other.append('None')
        
        object_type.append('TransferNode')
        name.append("Output@"+df_locaciones.Name.iloc[index])
        x.append('0')
        y.append('0')
        z.append('0')
        lenght.append(tamanho_server[0])
        width.append(tamanho_server[1])
        height.append(tamanho_server[2])
        path.append('0')
        prop.append('ExitedAddOnProcess')
        value.append('SalidaOutputDescarga')
        other.append('None')
        
        
    else:
        #es un vertice
        object_type.append('TransferNode')
        name.append(df_locaciones.Name.iloc[index])
        x.append('0')
        y.append('0')
        z.append('0')
        lenght.append(tamanho_server[0])
        width.append(tamanho_server[1])
        height.append(tamanho_server[2])
        path.append('0')
        prop.append('')
        value.append('')
        other.append('')

datos_dict = {
    'Tipo objeto': object_type,
    'Nombre': name, 
    'x':x,
    'y':y,
    'z':z,
    'lenght': lenght,
    'width': width,
    'height': height,
    'path': path,
    'prop': prop,
    'value': value,
    'other': other
}
df_objects= pd.DataFrame(datos_dict)

# %%
df_objects.to_csv(path_or_buf='C:/Users/dazac/Downloads/datos mina/datos produccion/creador_objetos.csv', sep='#', header=False, index=False)
